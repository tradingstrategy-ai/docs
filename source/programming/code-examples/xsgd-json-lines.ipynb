# %% [markdown]
# # Streaming JSONL data
#
# In this example, we demonstrate how to stream JSONL data from a URL and parse it into a dataframe and visualise the data. We will use the [XSGD-USDC pair on Uniswap V3](https://tradingstrategy.ai/trading-view/ethereum/uniswap-v3/xsgd-usdc-fee-5) token as an example.
#
# ## JSON lines
#
# JSON Lines is a convenient format for storing structured data that may be processed one record at a time. This is preferred method for getting large amounts of OHLCV data due to the ease of incremental processing and lower memory footprint
#
# JSON Lines is like JSON, but each new line (record) is a new JSON object. The basic structure of JSON Lines is very simple:
#
# ```json
# {"name": "John", "age": 30, "city": "New York"}
# {"name": "Jane", "age": 25, "city": "Chicago"}
# {"name": "Jim", "age": 35, "city": "Los Angeles"}
# ```
#
# In the above example, each line is a valid JSON object, and each line can be parsed independently of the other lines. This property makes JSON Lines ideal for data storage where new records are appended over time, such as log files. It's also good for data processing tasks that can be carried out in a line-by-line manner, such as Unix 'grep', 'sed', or 'awk'.
#
# In comparison, a regular JSON data would look like:
#
# ```json
# [
#   {"name": "John", "age": 30, "city": "New York"},
#   {"name": "Jane", "age": 25, "city": "Chicago"},
#   {"name": "Jim", "age": 35, "city": "Los Angeles"}
# ]
# ```
# In the above, you can see that the entire string has to be parsed as a whole to get the data, unlike JSON Lines where each line is independently a JSON object.

# %% [markdown]
# ## Data Streaming

# %%
import requests
import pandas as pd
import json

pair_url = "https://tradingstrategy.ai/api/candles-jsonl?pair_ids=2699634&time_bucket=1d"

def get_candles(url: str) -> pd.DataFrame:
    x = requests.get(url)

    data = x.text.split('\n')  # split by newline character

    json_objects = []
    for line in data:
        try:
            json_objects.append(json.loads(line))
        except:
            pass
        

    candles = pd.DataFrame(json_objects)
    candles.rename(columns = {'ts':'date','o':'open', 'h':'high','l':'low','c':'close','v':'volume'}, inplace = True)
    candles['timestamp'] = pd.to_datetime(candles['date'])
    candles = candles.set_index('date')
    return candles

pair_data = get_candles(pair_url)

display(pair_data.head())
# Out:
#                 open      high       low     close         volume   xr     b  \
# date
# 1623196800  0.751273  0.761408  0.751273  0.753983   46404.942246  1.0  None
# 1623283200  0.753983  0.754360  0.749023  0.754360   27170.926637  1.0  None
# 1623369600  0.754511  0.754511  0.754511  0.754511     556.739452  1.0  None
# 1623456000  0.749398  0.753380  0.733605  0.753380  126186.194150  1.0  None
# 1623542400  0.744022  0.751574  0.744022  0.751574   44663.119939  1.0  None
#
#                s    tc    bv    sv        p        sb        eb  \
# date
# 1623196800  None  None  None  None  2699634  12599483  12602480
# 1623283200  None  None  None  None  2699634  12607138  12608081
# 1623369600  None  None  None  None  2699634  12611519  12611519
# 1623456000  None  None  None  None  2699634  12618259  12619487
# 1623542400  None  None  None  None  2699634  12628856  12628860
#
#                                timestamp
# date
# 1623196800 1970-01-01 00:00:01.623196800
# 1623283200 1970-01-01 00:00:01.623283200
# 1623369600 1970-01-01 00:00:01.623369600
# 1623456000 1970-01-01 00:00:01.623456000
# 1623542400 1970-01-01 00:00:01.623542400

# %% [markdown]
# ## Data Visualisation

# %%
from tradingstrategy.charting.candle_chart import visualise_ohlcv

def get_figure(candles: pd.DataFrame, chart_name: str):
    return visualise_ohlcv(
        candles,
        height=600,
        theme="plotly_white",
        chart_name=chart_name,
        y_axis_name="Price",
        volume_axis_name="volume",
    )

fig = get_figure(pair_data, "XSGD/USDC")

fig.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.8/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/.pyenv/versions/3.10.8/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.pyenv/versions/3.10.8/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2263, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2273, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 13
#       3 def get_figure(candles: pd.DataFrame, chart_name: str):
#       4     return visualise_ohlcv(
#       5         candles,
#       6         height=600,
#    (...)
#      10         volume_axis_name="volume",
#      11     )
# ---> 13 fig = get_figure(pair_data, "XSGD/USDC")
#      15 fig.show()
#
# Cell In[2], line 4, in get_figure(candles, chart_name)
#       3 def get_figure(candles: pd.DataFrame, chart_name: str):
# ----> 4     return visualise_ohlcv(
#       5         candles,
#       6         height=600,
#       7         theme="plotly_white",
#       8         chart_name=chart_name,
#       9         y_axis_name="Price",
#      10         volume_axis_name="volume",
#      11     )
#
# File ~/work/tradingstrategy-ai/stuff/docs/deps/trade-executor/deps/trading-strategy/tradingstrategy/charting/candle_chart.py:249, in visualise_ohlcv(candles, chart_name, y_axis_name, volume_axis_name, height, theme, volume_bar_colour, volume_bar_mode, labels, num_detached_indicators, vertical_spacing, relative_sizing, subplot_names, subplot_font_size)
#     245 else:
#     246     # TODO: Legacy - deprecate
#     247     # Add change percentages on candle mouse hover
#     248     percentage_changes = ((candles['close'] - candles['open'])/candles['open']) * 100
# --> 249     text = ["Change: " + f"{percentage_changes[i]:.2f}%" for i in range(len(percentage_changes))]
#     251 candlesticks = go.Candlestick(
#     252     x=candles.index,
#     253     open=candles['open'],
#    (...)
#     259     hoverinfo="text",
#     260 )
#     263 if "volume" in candles.columns:
#
# File ~/work/tradingstrategy-ai/stuff/docs/deps/trade-executor/deps/trading-strategy/tradingstrategy/charting/candle_chart.py:249, in <listcomp>(.0)
#     245 else:
#     246     # TODO: Legacy - deprecate
#     247     # Add change percentages on candle mouse hover
#     248     percentage_changes = ((candles['close'] - candles['open'])/candles['open']) * 100
# --> 249     text = ["Change: " + f"{percentage_changes[i]:.2f}%" for i in range(len(percentage_changes))]
#     251 candlesticks = go.Candlestick(
#     252     x=candles.index,
#     253     open=candles['open'],
#    (...)
#     259     hoverinfo="text",
#     260 )
#     263 if "volume" in candles.columns:
#
# File ~/.pyenv/versions/3.10.8/lib/python3.10/site-packages/pandas/core/series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~/.pyenv/versions/3.10.8/lib/python3.10/site-packages/pandas/core/series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
#    1088 # Similar to Index.get_value, but we do not fall back to positional
# -> 1089 loc = self.index.get_loc(label)
#    1090 return self.index._get_values_for_loc(self, loc, label)
#
# File ~/.pyenv/versions/3.10.8/lib/python3.10/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 0
